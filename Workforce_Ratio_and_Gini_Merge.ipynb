# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
workforce_ratio = pd.read_csv("Resources/Workforce_ratio_df.csv")
correl_table = pd.read_csv("Resources/correl_table.csv")
gini_index = pd.read_csv("Resources/Gini_Index_Data_Cleaned.csv")

# %%
correl_table.replace('Congo (Brazzaville)', 'Congo, Rep.', inplace=True)
correl_table.replace('Congo (Kinshasa)', 'Congo, Dem. Rep.', inplace=True)
workforce_ratio.replace('Venezuela, RB', 'Venezuela', inplace=True)
workforce_ratio.replace('Yemen, RB', 'Yemen', inplace=True)
workforce_ratio.replace('Egypt, Arab Rep.', 'Egypt', inplace=True)
workforce_ratio.replace('Gambia, The', 'Gambia', inplace=True)
workforce_ratio.replace('Iran, Islamic Rep.', 'Iran', inplace=True)
workforce_ratio.replace('Hong Kong SAR, China', 'Hong Kong S.A.R., China', inplace=True)
workforce_ratio.replace('Russian Federation', 'Russia', inplace=True)
workforce_ratio.replace('Korea, Rep.', 'South Korea', inplace=True)
workforce_ratio.replace('Syrian Arab Republic', 'Syria', inplace=True)
correl_table.replace('Swaziland', 'Eswatini', inplace=True)
workforce_ratio.replace('Yemen, Rep.', 'Yemen', inplace=True)

# %%
correl_table_complete = pd.merge(workforce_ratio, correl_table, how="outer", on=["Country"])

# %%
correl_table_complete = correl_table_complete[['Country', 'Workforce Ratio Five Year Average', 'Happy', 'Economy', 'Family', 'Health', 'Freedom', 'Trust', 'Generous']]

# %%
no_ratio = correl_table_complete[correl_table_complete['Workforce Ratio Five Year Average'].isnull()]
no_ratio
# Out:
#                       Country  Workforce Ratio Five Year Average     Happy  \
# 233             World Average                                NaN       NaN
# 234                 Hong Kong                                NaN  5.448000
# 235               Ivory Coast                                NaN  4.273200
# 236                    Kosovo                                NaN  5.606200
# 237                Kyrgyzstan                                NaN  5.173400
# 238                      Laos                                NaN  4.792750
# 239                 Macedonia                                NaN  5.122000
# 240              North Cyprus                                NaN  5.758667
# 241           Northern Cyprus                                NaN  5.776500
# 242   Palestinian Territories                                NaN  4.736600
# 243                  Slovakia                                NaN  6.108400
# 244         Somaliland Region                                NaN  5.057000
# 245         Somaliland region                                NaN  5.057000
# 246                    Taiwan                                NaN  6.391000
# 247  Taiwan Province of China                                NaN  6.422000
# 248         Trinidad & Tobago                                NaN  6.192000
#
#       Economy    Family    Health   Freedom     Trust  Generous
# 233       NaN       NaN       NaN       NaN       NaN       NaN
# 234  1.434935  1.123848  1.029513  0.510217  0.316428  0.324937
# 235  0.546692  0.786338  0.111450  0.428399  0.131516  0.181253
# 236  0.878283  1.014491  0.609754  0.317748  0.039870  0.283790
# 237  0.542388  1.270746  0.615166  0.467967  0.037476  0.338840
# 238  0.688770  0.837933  0.481000  0.572648  0.201180  0.337178
# 239  0.990347  1.057893  0.679695  0.332789  0.059004  0.221355
# 240  1.288794  1.024881  0.866542  0.465811  0.154644  0.263919
# 241  1.246000  1.231500  0.975500  0.456000  0.158000  0.185000
# 242  0.656832  1.052303  0.613651  0.233628  0.093293  0.105445
# 243  1.246007  1.379746  0.772485  0.307047  0.023198  0.136569
# 244  0.255580  0.758620  0.331080  0.391300  0.367940  0.514790
# 245  0.188470  0.951520  0.438730  0.465820  0.399280  0.503180
# 246  1.355317  1.217102  0.860487  0.372542  0.080647  0.225428
# 247  1.433627  1.384565  0.793984  0.361467  0.063829  0.258360
# 248  1.227000  1.484500  0.638500  0.532000  0.017500  0.178000

# %%
no_happy = correl_table_complete[correl_table_complete['Happy'].isnull()]
no_happy
# Out:
#                    Country  Workforce Ratio Five Year Average  Happy  Economy  \
# 4               Arab World                          31.202839    NaN      NaN
# 10            Bahamas, The                          83.503662    NaN      NaN
# 13                Barbados                          89.031182    NaN      NaN
# 23       Brunei Darussalam                          80.612656    NaN      NaN
# 27              Cabo Verde                          77.232017    NaN      NaN
# ..                     ...                                ...    ...      ...
# 224                Vanuatu                          77.283397    NaN      NaN
# 227  Virgin Islands (U.S.)                          92.434781    NaN      NaN
# 228     West Bank and Gaza                          25.146510    NaN      NaN
# 229                  World                          66.629291    NaN      NaN
# 233          World Average                                NaN    NaN      NaN
#
#      Family  Health  Freedom  Trust  Generous
# 4       NaN     NaN      NaN    NaN       NaN
# 10      NaN     NaN      NaN    NaN       NaN
# 13      NaN     NaN      NaN    NaN       NaN
# 23      NaN     NaN      NaN    NaN       NaN
# 27      NaN     NaN      NaN    NaN       NaN
# ..      ...     ...      ...    ...       ...
# 224     NaN     NaN      NaN    NaN       NaN
# 227     NaN     NaN      NaN    NaN       NaN
# 228     NaN     NaN      NaN    NaN       NaN
# 229     NaN     NaN      NaN    NaN       NaN
# 233     NaN     NaN      NaN    NaN       NaN
#
# [79 rows x 9 columns]

# %%
no_happy[no_happy['Country'].str.contains("Arab")]
# Out:
#       Country  Workforce Ratio Five Year Average  Happy  Economy  Family  \
# 4  Arab World                          31.202839    NaN      NaN     NaN
#
#    Health  Freedom  Trust  Generous
# 4     NaN      NaN    NaN       NaN

# %%
correl_table_complete = pd.merge(workforce_ratio, correl_table, how="inner", on=["Country"])
correl_table_complete = correl_table_complete[['Country', 'Workforce Ratio Five Year Average', 'Happy', 'Economy', 'Family', 'Health', 'Freedom', 'Trust', 'Generous']]

# %%
correl_table_complete.head()
# Out:
#        Country  Workforce Ratio Five Year Average    Happy   Economy  \
# 0  Afghanistan                          27.311836  3.51280  0.357113
# 1      Albania                          72.239452  4.71260  0.938633
# 2      Algeria                          21.980925  5.66760  1.012963
# 3       Angola                          96.300743  3.87225  0.798380
# 4    Argentina                          67.997396  6.45940  1.111035
#
#      Family    Health   Freedom     Trust  Generous
# 0  0.409753  0.254707  0.117924  0.058094  0.267730
# 1  0.754931  0.787696  0.371898  0.043201  0.167887
# 2  1.074205  0.665057  0.178437  0.146099  0.069219
# 3  0.938368  0.133902  0.027432  0.071570  0.105269
# 4  1.330960  0.760895  0.481620  0.064308  0.092371

# %%
gini_index = gini_index[['Country', 'Gini Index Five Year Average']]
gini_index.replace("Cote d'Ivoir", 'Ivory Coast', inplace=True)
gini_index.replace("Egypt, Arab Rep.", 'Egypt', inplace=True)
gini_index.replace('Gambia, The', 'Gambia', inplace=True)
gini_index.replace('Iran, Islamic Rep.', 'Iran', inplace=True)
gini_index.replace('Russian Federation', 'Russia', inplace=True)

# %%
all_var_df = pd.merge(gini_index, correl_table_complete, how="outer", on=["Country"])

# %%
all_var_df.drop([109, 110, 111, 112, 113], inplace=True)

# %%
all_var_df
# Out:
#                   Country  Gini Index Five Year Average  \
# 0                 Albania                     33.266667
# 1                  Angola                     51.300000
# 2               Argentina                     41.533333
# 3                 Armenia                     33.225000
# 4                 Austria                     30.333333
# ..                    ...                           ...
# 165          Turkmenistan                           NaN
# 166  United Arab Emirates                           NaN
# 167            Uzbekistan                           NaN
# 168             Venezuela                           NaN
# 169                 Yemen                           NaN
#
#      Workforce Ratio Five Year Average    Happy   Economy    Family    Health  \
# 0                            72.239452  4.71260  0.938633  0.754931  0.787696
# 1                            96.300743  3.87225  0.798380  0.938368  0.133902
# 2                            67.997396  6.45940  1.111035  1.330960  0.760895
# 3                            71.844352  4.39320  0.839133  0.890873  0.697851
# 4                            82.749968  7.14200  1.398341  1.363963  0.883680
# ..                                 ...      ...       ...       ...       ...
# 165                          65.860098  5.58220  1.047483  1.365800  0.518129
# 166                          55.312159  6.74420  1.645227  1.069860  0.752196
# 167                          67.293723  6.04620  0.723758  1.434100  0.591725
# 168                          61.961743  5.53140  1.052468  1.323264  0.683741
# 169                           8.588724  3.62580  0.489313  0.865448  0.365440
#
#       Freedom     Trust  Generous
# 0    0.371898  0.043201  0.167887
# 1    0.027432  0.071570  0.105269
# 2    0.481620  0.064308  0.092371
# 3    0.216029  0.038767  0.082394
# 4    0.576929  0.214260  0.292400
# ..        ...       ...       ...
# 165  0.415890  0.183476  0.217677
# 166  0.538813  0.311982  0.267826
# 167  0.655988  0.267424  0.327523
# 168  0.213709  0.071444  0.057186
# 169  0.244175  0.067045  0.096929
#
# [165 rows x 10 columns]

# %%
no_gini = all_var_df[all_var_df['Gini Index Five Year Average'].isnull()]
no_gini
# Out:
#                       Country  Gini Index Five Year Average  \
# 114               Afghanistan                           NaN
# 115                   Algeria                           NaN
# 116                 Australia                           NaN
# 117                Azerbaijan                           NaN
# 118                   Bahrain                           NaN
# 119                    Belize                           NaN
# 120    Bosnia and Herzegovina                           NaN
# 121              Burkina Faso                           NaN
# 122                   Burundi                           NaN
# 123                  Cambodia                           NaN
# 124                  Cameroon                           NaN
# 125  Central African Republic                           NaN
# 126                      Chad                           NaN
# 127                   Comoros                           NaN
# 128          Congo, Dem. Rep.                           NaN
# 129               Congo, Rep.                           NaN
# 130                 Guatemala                           NaN
# 131                    Guinea                           NaN
# 132                     Haiti                           NaN
# 133   Hong Kong S.A.R., China                           NaN
# 134                     India                           NaN
# 135                      Iraq                           NaN
# 136                   Jamaica                           NaN
# 137                     Japan                           NaN
# 138                    Jordan                           NaN
# 139               South Korea                           NaN
# 140                    Kuwait                           NaN
# 141                   Lebanon                           NaN
# 142                     Libya                           NaN
# 143                Madagascar                           NaN
# 144                      Mali                           NaN
# 145                Mauritania                           NaN
# 146                   Morocco                           NaN
# 147                Mozambique                           NaN
# 148                     Nepal                           NaN
# 149               New Zealand                           NaN
# 150                 Nicaragua                           NaN
# 151                     Niger                           NaN
# 152                      Oman                           NaN
# 153               Puerto Rico                           NaN
# 20             Ivory Coast                         41.50
# 51                  Kosovo                         27.40
# 52         Kyrgyz Republic                         27.70
# 60                Maldives                         31.30
# 83   Sao Tome and Principe                         56.30
# 86         Slovak Republic                         25.85
# 90               St. Lucia                         51.20
# 97                   Tonga                         37.60
# 106     West Bank and Gaza                         33.70
#
#      Workforce Ratio Five Year Average  Happy  Economy  Family  Health  \
# 14                                 NaN    NaN      NaN     NaN     NaN
# 20                                 NaN    NaN      NaN     NaN     NaN
# 51                                 NaN    NaN      NaN     NaN     NaN
# 52                                 NaN    NaN      NaN     NaN     NaN
# 60                                 NaN    NaN      NaN     NaN     NaN
# 83                                 NaN    NaN      NaN     NaN     NaN
# 86                                 NaN    NaN      NaN     NaN     NaN
# 90                                 NaN    NaN      NaN     NaN     NaN
# 97                                 NaN    NaN      NaN     NaN     NaN
# 106                                NaN    NaN      NaN     NaN     NaN
#
#      Freedom  Trust  Generous
# 14       NaN    NaN       NaN
# 20       NaN    NaN       NaN
# 51       NaN    NaN       NaN
# 52       NaN    NaN       NaN
# 60       NaN    NaN       NaN
# 83       NaN    NaN       NaN
# 86       NaN    NaN       NaN
# 90       NaN    NaN       NaN
# 97       NaN    NaN       NaN
# 106      NaN    NaN       NaN

# %%
correl_table[correl_table['Country'].str.contains("Cabo")]
# Out:
# Empty DataFrame
# Columns: [Country, Happy, Economy, Family, Health, Freedom, Trust, Generous]
# Index: []

# %%
all_var_avg = pd.merge(gini_index, correl_table_complete, how="inner", on=["Country"])
all_var_avg
# Out:
#           Country  Gini Index Five Year Average  \
# 0         Albania                     33.266667
# 1          Angola                     51.300000
# 2       Argentina                     41.533333
# 3         Armenia                     33.225000
# 4         Austria                     30.333333
# ..            ...                           ...
# 94  United States                     41.100000
# 95        Uruguay                     39.750000
# 96        Vietnam                     35.500000
# 97         Zambia                     57.100000
# 98       Zimbabwe                     44.300000
#
#     Workforce Ratio Five Year Average    Happy   Economy    Family    Health  \
# 0                           72.239452  4.71260  0.938633  0.754931  0.787696
# 1                           96.300743  3.87225  0.798380  0.938368  0.133902
# 2                           67.997396  6.45940  1.111035  1.330960  0.760895
# 3                           71.844352  4.39320  0.839133  0.890873  0.697851
# 4                           82.749968  7.14200  1.398341  1.363963  0.883680
# ..                                ...      ...       ...       ...       ...
# 94                          82.045499  6.99880  1.455946  1.328570  0.821615
# 95                          75.257850  6.43120  1.135558  1.315312  0.782929
# 96                          88.183501  5.15460  0.723416  1.138384  0.722700
# 97                          88.284661  4.58440  0.571761  0.932381  0.302761
# 98                          87.475831  4.00660  0.344051  1.007727  0.274403
#
#      Freedom     Trust  Generous
# 0   0.371898  0.043201  0.167887
# 1   0.027432  0.071570  0.105269
# 2   0.481620  0.064308  0.092371
# 3   0.216029  0.038767  0.082394
# 4   0.576929  0.214260  0.292400
# ..       ...       ...       ...
# 94  0.506882  0.140844  0.355080
# 95  0.574978  0.188516  0.169011
# 96  0.577207  0.091921  0.195664
# 97  0.462099  0.097337  0.218430
# 98  0.323257  0.089997  0.169409
#
# [99 rows x 10 columns]

# %%
all_var_avg.to_csv(r'Resources/all_variables_avg.csv')
