# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
#Load resources files from world happiness dataset
wor_hap_2015 = pd.read_csv("Resources/2015.csv")
wor_hap_2016 = pd.read_csv("Resources/2016.csv")    
wor_hap_2017 = pd.read_csv("Resources/2017.csv")
wor_hap_2018 = pd.read_csv("Resources/2018.csv")
wor_hap_2019 = pd.read_csv("Resources/2019.csv")

# %%
#wor_hap_2015.head()

# %%
#2015 year added in to 2015 Happy Data
year15 = []
year15 = [2015]*len(wor_hap_2015)

wor_hap_2015['year'] = year15

clean_hap_2015 = wor_hap_2015

#cleaning names/removing columns
del clean_hap_2015['Standard Error']
del clean_hap_2015['Region']
del clean_hap_2015['Dystopia Residual']

clean_hap_2015.head()
# Out:
#        Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0  Switzerland               1            7.587                   1.39651
# 1      Iceland               2            7.561                   1.30232
# 2      Denmark               3            7.527                   1.32548
# 3       Norway               4            7.522                   1.45900
# 4       Canada               5            7.427                   1.32629
#
#     Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0  1.34951                   0.94143  0.66557                        0.41978
# 1  1.40223                   0.94784  0.62877                        0.14145
# 2  1.36058                   0.87464  0.64938                        0.48357
# 3  1.33095                   0.88521  0.66973                        0.36503
# 4  1.32261                   0.90563  0.63297                        0.32957
#
#    Generosity  year
# 0     0.29678  2015
# ...

# %%
#wor_hap_2016.head()

# %%
#2016 year added in to 2016 Happy Data
year16 = []
year16 = [2016]*len(wor_hap_2016)
  
wor_hap_2016['year'] = year16

clean_hap_2016 = wor_hap_2016

#cleaning names/removing columns

del clean_hap_2016['Lower Confidence Interval']
del clean_hap_2016['Upper Confidence Interval']
del clean_hap_2016['Region']
del clean_hap_2016['Dystopia Residual']

clean_hap_2016.head()
# Out:
#        Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0      Denmark               1            7.526                   1.44178
# 1  Switzerland               2            7.509                   1.52733
# 2      Iceland               3            7.501                   1.42666
# 3       Norway               4            7.498                   1.57744
# 4      Finland               5            7.413                   1.40598
#
#     Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0  1.16374                   0.79504  0.57941                        0.44453
# 1  1.14524                   0.86303  0.58557                        0.41203
# 2  1.18326                   0.86733  0.56624                        0.14975
# 3  1.12690                   0.79579  0.59609                        0.35776
# 4  1.13464                   0.81091  0.57104                        0.41004
#
#    Generosity  year
# 0     0.36171  2016
# ...

# %%
#2017 year added in to 2017 Happy Data
year17 = []
year17 = [2017]*len(wor_hap_2017)
  
wor_hap_2017['year'] = year17

clean_hap_2017 = wor_hap_2017

#cleaning names/removing columns

del clean_hap_2017['Whisker.high']
del clean_hap_2017['Whisker.low']
del clean_hap_2017['Dystopia.Residual']

clean_hap_2017 = clean_hap_2017.rename(columns = {'Happiness.Rank': "Happiness Rank", 'Happiness.Score':'Happiness Score', 'Economy..GDP.per.Capita.': 'Economy (GDP per Capita)'})
clean_hap_2017 = clean_hap_2017.rename(columns = {'Health..Life.Expectancy.':'Health (Life Expectancy)', 'Trust..Government.Corruption.':'Trust (Government Corruption)'})

#fix the order to be consistent with other years
clean_hap_2017 = clean_hap_2017[['Country','Happiness Rank','Happiness Score','Economy (GDP per Capita)','Family','Health (Life Expectancy)','Freedom','Trust (Government Corruption)','Generosity','year']]

clean_hap_2017.head()
# Out:
#        Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0       Norway               1            7.537                  1.616463
# 1      Denmark               2            7.522                  1.482383
# 2      Iceland               3            7.504                  1.480633
# 3  Switzerland               4            7.494                  1.564980
# 4      Finland               5            7.469                  1.443572
#
#      Family  Health (Life Expectancy)   Freedom  \
# 0  1.533524                  0.796667  0.635423
# 1  1.551122                  0.792566  0.626007
# 2  1.610574                  0.833552  0.627163
# 3  1.516912                  0.858131  0.620071
# 4  1.540247                  0.809158  0.617951
#
#    Trust (Government Corruption)  Generosity  year
# 0                       0.315964    0.362012  2017
# 1                       0.400770    0.355280  2017
# 2                       0.153527    0.475540  2017
# ...

# %%
#2018 year added in to 2018 Happy Data
year18 = []
year18 = [2018]*len(wor_hap_2018)
  
wor_hap_2018['year'] = year18

clean_hap_2018 = wor_hap_2018

#cleaning names/removing columns
clean_hap_2018 = clean_hap_2018.rename(columns = {'Overall rank': 'Happiness Rank','Country or region':'Country','Score':'Happiness Score' })
clean_hap_2018 = clean_hap_2018.rename(columns = {'GDP per capita':'Economy (GDP per Capita)', 'Social support':'Family', 'Healthy life expectancy':'Health (Life Expectancy)'})
clean_hap_2018 = clean_hap_2018.rename(columns = {'Freedom to make life choices':'Freedom', 'Perceptions of corruption':'Trust (Government Corruption)'})

#fix the order to be consistent with other years
clean_hap_2018 = clean_hap_2018[['Country','Happiness Rank','Happiness Score','Economy (GDP per Capita)','Family','Health (Life Expectancy)','Freedom','Trust (Government Corruption)','Generosity','year']]

clean_hap_2018.head()
# Out:
#        Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0      Finland               1            7.632                     1.305
# 1       Norway               2            7.594                     1.456
# 2      Denmark               3            7.555                     1.351
# 3      Iceland               4            7.495                     1.343
# 4  Switzerland               5            7.487                     1.420
#
#    Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0   1.592                     0.874    0.681                          0.393
# 1   1.582                     0.861    0.686                          0.340
# 2   1.590                     0.868    0.683                          0.408
# 3   1.644                     0.914    0.677                          0.138
# 4   1.549                     0.927    0.660                          0.357
#
#    Generosity  year
# 0       0.202  2018
# 1       0.286  2018
# ...

# %%
#2019 year added in to 2019 Happy Data
year19 = []
year19 = [2019]*len(wor_hap_2019)
  
wor_hap_2019['year'] = year19

clean_hap_2019 = wor_hap_2019

#cleaning names/removing columns
clean_hap_2019 = clean_hap_2019.rename(columns = {'Overall rank': 'Happiness Rank','Country or region':'Country','Score':'Happiness Score' })
clean_hap_2019 = clean_hap_2019.rename(columns = {'GDP per capita':'Economy (GDP per Capita)', 'Social support':'Family', 'Healthy life expectancy':'Health (Life Expectancy)'})
clean_hap_2019 = clean_hap_2019.rename(columns = {'Freedom to make life choices':'Freedom', 'Perceptions of corruption':'Trust (Government Corruption)'})

#fix the order to be consistent with other years
clean_hap_2019 = clean_hap_2019[['Country','Happiness Rank','Happiness Score','Economy (GDP per Capita)','Family','Health (Life Expectancy)','Freedom','Trust (Government Corruption)','Generosity','year']]


clean_hap_2019.head()
# Out:
#        Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0      Finland               1            7.769                     1.340
# 1      Denmark               2            7.600                     1.383
# 2       Norway               3            7.554                     1.488
# 3      Iceland               4            7.494                     1.380
# 4  Netherlands               5            7.488                     1.396
#
#    Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0   1.587                     0.986    0.596                          0.393
# 1   1.573                     0.996    0.592                          0.410
# 2   1.582                     1.028    0.603                          0.341
# 3   1.624                     1.026    0.591                          0.118
# 4   1.522                     0.999    0.557                          0.298
#
#    Generosity  year
# 0       0.153  2019
# 1       0.252  2019
# ...

# %%
# one merge method - #merge the data files together 

merged_hap_15_16 = pd.merge(clean_hap_2015, clean_hap_2016,  on='Country', how='left')
merged_hap_15_17 = pd.merge(merged_hap_15_16, clean_hap_2017, on='Country', how='left')
merged_hap_15_18 = pd.merge(merged_hap_15_17, clean_hap_2018, on='Country', how='left')
merged_hap_15_19 = pd.merge(merged_hap_15_18, clean_hap_2019, on='Country', how='left')

merged_hap_15_19.head()
# Out:
#        Country  Happiness Rank_x  Happiness Score_x  \
# 0  Switzerland                 1              7.587
# 1      Iceland                 2              7.561
# 2      Denmark                 3              7.527
# 3       Norway                 4              7.522
# 4       Canada                 5              7.427
#
#    Economy (GDP per Capita)_x  Family_x  Health (Life Expectancy)_x  \
# 0                     1.39651   1.34951                     0.94143
# 1                     1.30232   1.40223                     0.94784
# 2                     1.32548   1.36058                     0.87464
# 3                     1.45900   1.33095                     0.88521
# 4                     1.32629   1.32261                     0.90563
#
#    Freedom_x  Trust (Government Corruption)_x  Generosity_x  year_x  ...  \
# 0    0.66557                          0.41978       0.29678    2015  ...
# 1    0.62877                          0.14145       0.43630    2015  ...
# ...

# %%
#stacking all data tables together via concatenation (by country, by year)
#https://www.freecodecamp.org/news/how-to-combine-multiple-csv-files-with-8-lines-of-code-265183e0854/
stack_15_16 = pd.concat([clean_hap_2015, clean_hap_2016, clean_hap_2017, clean_hap_2018, clean_hap_2019], axis = 0)

stack_15_16
# Out:
#                       Country  Happiness Rank  Happiness Score  \
# 0                 Switzerland               1            7.587
# 1                     Iceland               2            7.561
# 2                     Denmark               3            7.527
# 3                      Norway               4            7.522
# 4                      Canada               5            7.427
# ..                        ...             ...              ...
# 151                    Rwanda             152            3.334
# 152                  Tanzania             153            3.231
# 153               Afghanistan             154            3.203
# 154  Central African Republic             155            3.083
# 155               South Sudan             156            2.853
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# ...

# %%
#building a table of summary statistics by year - all countries

basic_data_year = stack_15_16.groupby('year').agg([np.mean, np.median, np.min, np.max, np.std])
basic_data_year
# Out:
#      Happiness Rank                             Happiness Score          \
#                mean median amin amax        std            mean  median
# year
# 2015      79.493671   79.5    1  158  45.754363        5.375734  5.2325
# 2016      78.980892   79.0    1  157  45.466030        5.382185  5.3140
# 2017      78.000000   78.0    1  155  44.888751        5.354019  5.2790
# 2018      78.500000   78.5    1  156  45.177428        5.375917  5.3780
# 2019      78.500000   78.5    1  156  45.177428        5.407096  5.3795
#
#                               ... Trust (Government Corruption)            \
#        amin   amax       std  ...                          mean    median
# year                          ...
# 2015  2.839  7.587  1.145010  ...                      0.143422  0.107220
# 2016  2.905  7.526  1.141674  ...                      0.137624  0.105470
# 2017  2.693  7.537  1.131230  ...                      0.123120  0.089848
# ...

# %%
#building a table of summary statistics by country

basic_data_country = stack_15_16.groupby('Country').agg([np.mean, np.median, np.min, np.max, np.std])
basic_data_country
# Out:
#             Happiness Rank                             Happiness Score  \
#                       mean median amin amax        std            mean
# Country
# Afghanistan          149.4  153.0  141  154   6.024948         3.51280
# Albania              106.4  109.0   95  112   6.618157         4.71260
# Algeria               66.2   68.0   38   88  21.004761         5.66760
# Angola               140.0  140.5  137  142   2.160247         3.87225
# Argentina             31.2   29.0   24   47   9.148770         6.45940
# ...                    ...    ...  ...  ...        ...             ...
# Venezuela             71.8   82.0   23  108  37.016213         5.53140
# Vietnam               90.8   94.0   75   96   8.871302         5.15460
# Yemen                146.4  147.0  136  152   6.348228         3.62580
# Zambia               114.0  116.0   85  138  20.037465         4.58440
# Zimbabwe             134.8  138.0  115  146  12.517987         4.00660
#
# ...

# %%
# building a correlation table
# Happiness Rank	Happiness Score	Economy (GDP per Capita)	Family	Health (Life Expectancy)	Freedom	Trust (Government Corruption)	Generosity
happy_score = basic_data_country['Happiness Score', 'mean']
economy_score = basic_data_country['Economy (GDP per Capita)', 'mean']
family_score = basic_data_country['Family', 'mean']
health_score = basic_data_country['Health (Life Expectancy)', 'mean']
freedom_score = basic_data_country['Freedom', 'mean']
trust_score = basic_data_country['Trust (Government Corruption)', 'mean']
generous_score = basic_data_country['Generosity', 'mean']

# make a new dictionary

correl_table = { 
    'Happy': happy_score, 
    "Economy": economy_score, 
    "Family": family_score,
    "Health": health_score,
    "Freedom": freedom_score,
    "Trust": trust_score,
    "Generous": generous_score
    }

correl_table = pd.DataFrame(correl_table)
correl_table
# Out:
#                Happy   Economy    Family    Health   Freedom     Trust  \
# Country
# Afghanistan  3.51280  0.357113  0.409753  0.254707  0.117924  0.058094
# Albania      4.71260  0.938633  0.754931  0.787696  0.371898  0.043201
# Algeria      5.66760  1.012963  1.074205  0.665057  0.178437  0.146099
# Angola       3.87225  0.798380  0.938368  0.133902  0.027433  0.071570
# Argentina    6.45940  1.111035  1.330960  0.760895  0.481620  0.064308
# ...              ...       ...       ...       ...       ...       ...
# Venezuela    5.53140  1.052468  1.323264  0.683741  0.213709  0.071444
# Vietnam      5.15460  0.723416  1.138384  0.722700  0.577207  0.091921
# Yemen        3.62580  0.489313  0.865448  0.365440  0.244175  0.067045
# Zambia       4.58440  0.571761  0.932381  0.302761  0.462099  0.097337
# Zimbabwe     4.00660  0.344051  1.007727  0.274403  0.323257  0.089997
#
#              Generous
# Country
# Afghanistan  0.267730
# Albania      0.167887
# Algeria      0.069219
# ...

# %%
#example of looking at countries with biggest change in Happiness Rank using sort descending

basic_data_country_sort = basic_data_country.sort_values(by=('Happiness Rank','std'), ascending=False)
basic_data_country_sort
# Out:
#                          Happiness Rank                              \
#                                    mean median amin amax        std
# Country
# Venezuela                         71.80   82.0   23  108  37.016213
# Swaziland                        118.00  118.0  101  135  24.041631
# Lesotho                          130.25  140.0   97  144  22.261701
# Ivory Coast                      124.80  128.0   99  151  21.684096
# Benin                            137.80  143.0  102  155  21.440616
# ...                                 ...    ...  ...  ...        ...
# Oman                              22.00   22.0   22   22        NaN
# Puerto Rico                       15.00   15.0   15   15        NaN
# Somaliland Region                 97.00   97.0   97   97        NaN
# Somaliland region                 91.00   91.0   91   91        NaN
# Taiwan Province of China          33.00   33.0   33   33        NaN
#
# ...

# %%
def linreg(x_values, y_values, title, coordinates):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,coordinates,fontsize=15,color="red")
    plt.xlabel('Happy')
    plt.ylabel(title)
    print(f"The r value is: {rvalue}")
    plt.show()

# %%
correl_table.plot(kind='scatter', x='Happy', y='Economy')
plt.title("Economy vs Mean Happiness Score")
plt.grid()
x_values = correl_table["Happy"]

y_values = correl_table["Economy"]
linreg(correl_table["Happy"],correl_table["Economy"], "Economy", (3, 1.6))
# Out:
# The r value is: 0.8034298439343017

# %%
correl_table.plot(kind='scatter', x='Happy', y='Family')
plt.title("Family vs Mean Happiness Score")

plt.grid()
x_values = correl_table["Happy"]

y_values = correl_table["Family"]
linreg(correl_table["Happy"],correl_table["Family"], "Family", (5, 0.2))
# Out:
# The r value is: 0.7556695571726789

# %%
correl_table.plot(kind='scatter', x='Happy', y='Health')
plt.title("Health vs Mean Happiness Score")

plt.grid()
x_values = correl_table["Happy"]

y_values = correl_table["Health"]
linreg(correl_table["Happy"],correl_table["Health"], "Health", (5.5, 0.1))
# Out:
# The r value is: 0.772317439710236

# %%
correl_table.plot(kind='scatter', x='Happy', y='Freedom')
plt.title("Freedom vs Mean Happiness Score")

plt.grid()
x_values = correl_table["Happy"]

y_values = correl_table["Freedom"]
linreg(correl_table["Happy"],correl_table["Freedom"], "Freedom", (5.7, 0.1))
# Out:
# The r value is: 0.589061507127668

# %%
correl_table.plot(kind='scatter', x='Happy', y='Trust')
plt.title("Trust vs Mean Happiness Score")

plt.grid()
x_values = correl_table["Happy"]

y_values = correl_table["Trust"]
linreg(correl_table["Happy"],correl_table["Trust"], "Trust", (3, 0.4))
# Out:
# The r value is: 0.37700234805940325

# %%
correl_table.plot(kind='scatter', x='Happy', y='Generous')
plt.title("Generosity vs Mean Happiness Score")

plt.grid()
x_values = correl_table["Happy"]

y_values = correl_table["Generous"]
linreg(correl_table["Happy"],correl_table["Generous"], "Generous", (3, 0.6))
# Out:
# The r value is: 0.1417041750637646
