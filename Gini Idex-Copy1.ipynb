# %%
import pandas as pd
import numpy as np

# %%
gini_df = pd.read_csv("Resources/Gini_Index_Data.csv")

# %%
gini_df
# Out:
#                                 Series Name  Series Code  Country Name  \
# 0          Gini index (World Bank estimate)  SI.POV.GINI   Afghanistan
# 1          Gini index (World Bank estimate)  SI.POV.GINI       Albania
# 2          Gini index (World Bank estimate)  SI.POV.GINI       Algeria
# 3          Gini index (World Bank estimate)  SI.POV.GINI        Angola
# 4          Gini index (World Bank estimate)  SI.POV.GINI     Argentina
# ..                                      ...          ...           ...
# 185                                     NaN          NaN           NaN
# 186                                     NaN          NaN           NaN
# 187                                     NaN          NaN           NaN
# 188  Data from database: Poverty and Equity          NaN           NaN
# 189                Last Updated: 10/07/2020          NaN           NaN
#
#      Country Code  2015[YR2015]  2016[YR2016]  2017[YR2017]  2018[YR2018]  \
# ...

# %%
gini_df = gini_df[[' Country Code', ' 2015[YR2015]', ' 2016[YR2016]', ' 2017[YR2017]', ' 2018[YR2018]', ' 2019[YR2019]']]
gini_df.head()
len(gini_df.index)
# Out:
# 190

# %%
gini_df.rename(inplace=True, columns={' Country Code': 'Country Code', 
                                      ' 2015[YR2015]': '2015[YR2015]',
                                      ' 2016[YR2016]': '2016[YR2016]',
                                      ' 2017[YR2017]': '2017[YR2017]',
                                      ' 2018[YR2018]': '2018[YR2018]',
                                      ' 2019[YR2019]': '2019[YR2019]'
                                     })
# Out:
# C:\Users\hanna\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:4301: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
gini_df.head()
# Out:
#   Country Code 2015[YR2015] 2016[YR2016] 2017[YR2017] 2018[YR2018]  \
# 0          AFG           ..           ..           ..           ..
# 1          ALB         32.9         33.7         33.2           ..
# 2          DZA           ..           ..           ..           ..
# 3          AGO           ..           ..           ..         51.3
# 4          ARG           ..           42         41.2         41.4
#
#   2019[YR2019]
# 0           ..
# 1           ..
# 2           ..
# 3           ..
# 4           ..

# %%
null_values = gini_df.loc[(gini_df["2015[YR2015]"] == "..") & (gini_df["2016[YR2016]"] == "..") & (gini_df["2017[YR2017]"] == "..") & (gini_df["2018[YR2018]"] == "..") & (gini_df["2019[YR2019]"] == "..")]
null_index = null_values.index

new_gini_df = gini_df.replace("..", np.nan)
new_gini_df.head()
# Out:
#   Country Code 2015[YR2015] 2016[YR2016] 2017[YR2017] 2018[YR2018]  \
# 0          AFG          NaN          NaN          NaN          NaN
# 1          ALB         32.9         33.7         33.2          NaN
# 2          DZA          NaN          NaN          NaN          NaN
# 3          AGO          NaN          NaN          NaN         51.3
# 4          ARG          NaN           42         41.2         41.4
#
#    2019[YR2019]
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
gini2_df = new_gini_df.drop(null_index)
gini2_df.head()
# Out:
#   Country Code 2015[YR2015] 2016[YR2016] 2017[YR2017] 2018[YR2018]  \
# 1          ALB         32.9         33.7         33.2          NaN
# 3          AGO          NaN          NaN          NaN         51.3
# 4          ARG          NaN           42         41.2         41.4
# 5          ARM         32.4         32.5         33.6         34.4
# 7          AUT         30.5         30.8         29.7          NaN
#
#    2019[YR2019]
# 1           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 7           NaN

# %%
gini2_df['2015[YR2015]'] = gini2_df['2015[YR2015]'].astype(float)
gini2_df['2016[YR2016]'] = gini2_df['2016[YR2016]'].astype(float)
gini2_df['2017[YR2017]'] = gini2_df['2017[YR2017]'].astype(float)
gini2_df['2018[YR2018]'] = gini2_df['2018[YR2018]'].astype(float)
gini2_df['2019[YR2019]'] = gini2_df['2019[YR2019]'].astype(float)

# %%
gini3_df = gini2_df.set_index("Country Name", inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-3017024ee1d4> in <module>
# ----> 1 gini3_df = gini2_df.set_index("Country Name", inplace=True)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4546
#    4547         if missing:
# -> 4548             raise KeyError(f"None of {missing} are in the columns")
#    4549
#    4550         if inplace:
#
# KeyError: "None of ['Country Name'] are in the columns"

# %%
gini2_df.head()

gini2_df = gini2_df.drop(["level_0", "index"], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-5555a9ea538d> in <module>
#       1 gini2_df.head()
#       2
# ----> 3 gini2_df = gini2_df.drop(["level_0", "index"], axis=1)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4165             level=level,
#    4166             inplace=inplace,
# -> 4167             errors=errors,
#    4168         )
#    4169
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3876         for axis, labels in axes.items():
#    3877             if labels is not None:
# -> 3878                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3879
#    3880         if inplace:
#
# ...

# %%
gini2_df["Gini Index Five Year Average"] = gini2_df.mean(numeric_only=True, axis=1)
gini2_df.head()
# Out:
#   Country Code  2015[YR2015]  2016[YR2016]  2017[YR2017]  2018[YR2018]  \
# 1          ALB          32.9          33.7          33.2           NaN
# 3          AGO           NaN           NaN           NaN          51.3
# 4          ARG           NaN          42.0          41.2          41.4
# 5          ARM          32.4          32.5          33.6          34.4
# 7          AUT          30.5          30.8          29.7           NaN
#
#    2019[YR2019]  Gini Index Five Year Average
# 1           NaN                     33.266667
# 3           NaN                     51.300000
# 4           NaN                     41.533333
# 5           NaN                     33.225000
# 7           NaN                     30.333333

# %%
gini2_df.dtypes
# Out:
# Country Code                     object
# 2015[YR2015]                    float64
# 2016[YR2016]                    float64
# 2017[YR2017]                    float64
# 2018[YR2018]                    float64
# 2019[YR2019]                    float64
# Gini Index Five Year Average    float64
# dtype: object

# %%
gini2_df.to_csv(r'Resources/Gini_Index_Data.csv')
