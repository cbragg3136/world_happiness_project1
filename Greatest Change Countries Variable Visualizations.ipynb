# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
world_happy_by_year = pd.read_csv("Resources/yearly_country_data.csv")
world_happy_by_year
# Out:
#          Country     Happy   Economy    Family     Health   Freedom  Generous  \
# 0    Afghanistan  3.982855  7.500539  0.528597  53.200001  0.388928  0.089091
# 1    Afghanistan  4.220169  7.497038  0.559072  53.000000  0.522566  0.051365
# 2    Afghanistan  2.661718  7.497755  0.490880  52.799999  0.427011 -0.112198
# 3    Afghanistan  2.694303  7.494588  0.507516  52.599998  0.373536 -0.084888
# 4    Afghanistan  2.566900  7.462861  0.470367  52.590000  0.396573 -0.096429
# ..           ...       ...       ...       ...        ...       ...       ...
# 716     Zimbabwe  3.703191  7.556052  0.735800  53.799999  0.667193 -0.097354
# 717     Zimbabwe  3.735400  7.538829  0.768425  54.400002  0.732971 -0.068105
# 718     Zimbabwe  3.638300  7.549491  0.754147  55.000000  0.752826 -0.069670
# 719     Zimbabwe  3.616480  7.553395  0.775388  55.599998  0.762675 -0.038384
# 720     Zimbabwe  3.299200  7.865712  0.763093  55.617260  0.711458 -0.072064
#
#        Trust   Year
# ...

# %%
afghanistan = world_happy_by_year.loc[world_happy_by_year['Country'] == 'Afghanistan']
afghanistan
# Out:
#        Country     Happy   Economy    Family     Health   Freedom  Generous  \
# 0  Afghanistan  3.982855  7.500539  0.528597  53.200001  0.388928  0.089091
# 1  Afghanistan  4.220169  7.497038  0.559072  53.000000  0.522566  0.051365
# 2  Afghanistan  2.661718  7.497755  0.490880  52.799999  0.427011 -0.112198
# 3  Afghanistan  2.694303  7.494588  0.507516  52.599998  0.373536 -0.084888
# 4  Afghanistan  2.566900  7.462861  0.470367  52.590000  0.396573 -0.096429
#
#      Trust   Year
# 0  0.880638  2015
# 1  0.793246  2016
# 2  0.954393  2017
# 3  0.927606  2018
# 4  0.933687  2019

# %%
Liberia = world_happy_by_year.loc[world_happy_by_year['Country'] == 'Liberia']
Liberia
# Out:
#      Country     Happy   Economy    Family     Health   Freedom  Generous  \
# 359  Liberia  2.701591  6.665998  0.637666  53.700001  0.671431 -0.014139
# 360  Liberia  3.354676  6.624805  0.642615  54.500000  0.763476  0.080516
# 361  Liberia  4.424491  6.623784  0.684867  55.299999  0.733390  0.035449
# 362  Liberia  4.134853  6.630170  0.726750  56.099998  0.765770  0.096003
# 363  Liberia  4.557900  7.054380  0.709281  56.096313  0.735269  0.042273
#
#        Trust   Year
# 359  0.902673  2015
# 360  0.901267  2016
# 361  0.866806  2017
# 362  0.867924  2018
# 363  0.856376  2019

# %%
plt.plot(afghanistan['Year'], afghanistan['Family'], marker='s', color='pink', label='Family')
plt.xlabel('Year')
plt.ylabel('Family')
plt.title('Change in Family in Afghanistan')
plt.legend()
plt.savefig("Analysis_Figures_Images/family_afghanistan.png")

# %%
plt.plot(afghanistan['Year'], afghanistan['Freedom'], marker='*', color='red', label='Freedom')
plt.xlabel('Year')
plt.ylabel('Freedom')
plt.title('Change in Sense of Freedom in Afghanistan')
plt.legend()
plt.savefig("Analysis_Figures_Images/freedom_afghanistan.png")

# %%
plt.plot(afghanistan['Year'], afghanistan['Generous'], marker='p', color='purple', label='Generosity')
plt.xlabel('Year')
plt.ylabel('Generosity')
plt.title('Change in Generosity in Afghanistan')
plt.legend()
plt.savefig("Analysis_Figures_Images/generosity_afghanistan.png")

# %%
plt.plot(afghanistan['Year'], afghanistan['Trust '], marker='4', color='orange', label='Trust')
plt.xlabel('Year')
plt.ylabel('Mistrust')
plt.title('Change in Mistrust of Government and Business in Afghanistan')
plt.legend()
plt.savefig("Analysis_Figures_Images/trust_afghanistan.png")

# %%
plt.plot(afghanistan['Year'], afghanistan['Health'], marker='P', color='blue', label='Health')
plt.xlabel('Year')
plt.ylabel('Health')
plt.title('Change in Health in Afghanistan')
plt.legend()
plt.savefig("Analysis_Figures_Images/health_afghanistan.png")

# %%
plt.plot(afghanistan['Year'], afghanistan['Economy'], marker='^', color='black', label='Economy')
plt.xlabel('Year')
plt.ylabel('Economy')
plt.title('Change in Economy in Afghanistan')
plt.legend()
plt.savefig("Analysis_Figures_Images/economy_afghanistan.png")

# %%
plt.plot(afghanistan['Year'], afghanistan['Happy'], marker='o', color='green', label='Happiness')
plt.xlabel('Year')
plt.ylabel('Happiness')
plt.title('Change in Happiness in Afghanistan')
plt.legend()
plt.savefig("Analysis_Figures_Images/happiness_afghanistan.png")

# %%
plt.plot(Liberia['Year'], Liberia['Trust '], marker='4', color='orange', label='Trust')
plt.xlabel('Year')
plt.ylabel('Mistrust')
plt.title('Change in Misrust of Government and Buisnesses in Liberia')
plt.legend(loc='upper right')
plt.savefig("Analysis_Figures_Images/trust_liberia.png")

# %%
plt.plot(Liberia['Year'], Liberia['Generous'], marker='p', color='purple', label='Generosity')
plt.xlabel('Year')
plt.ylabel('Generosity')
plt.title('Change in Generosity in Liberia')
plt.legend()
plt.savefig("Analysis_Figures_Images/generosity_liberia.png")

# %%
plt.plot(Liberia['Year'], Liberia['Freedom'], marker='*', color='red', label='Freedom')
plt.xlabel('Year')
plt.ylabel('Freedom')
plt.title('Change in Feeling of Freedom in Liberia')
plt.legend()
plt.savefig("Analysis_Figures_Images/freedom_liberia.png")

# %%
plt.plot(Liberia['Year'], Liberia['Family'], marker='s', color='pink', label='Family')
plt.xlabel('Year')
plt.ylabel('Family')
plt.title('Change in Sense of Family and Social Suppport in Liberia')
plt.legend()
plt.savefig("Analysis_Figures_Images/family_liberia.png")

# %%
plt.plot(Liberia['Year'], Liberia['Health'], marker='P', color='blue', label='Health')
plt.xlabel('Year')
plt.ylabel('Health')
plt.title('Change in Health in Liberia')
plt.legend()
plt.savefig("Analysis_Figures_Images/health_liberia.png")

# %%
plt.plot(Liberia['Year'], Liberia['Happy'], marker='o', color='green', label='Happiness')
plt.xlabel('Year')
plt.ylabel('Happiness')
plt.title('Change in Happiness in Liberia')
plt.legend()
plt.savefig("Analysis_Figures_Images/happiness_liberia.png")

# %%
plt.plot(Liberia['Year'], Liberia['Economy'], marker='^', color='black', label='Economy')
plt.xlabel('Year')
plt.ylabel('Economy')
plt.title('Change in Economy in Liberia')
plt.legend()
plt.savefig("Analysis_Figures_Images/Economy_Liberia.png")
